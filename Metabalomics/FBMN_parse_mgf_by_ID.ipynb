# %% [markdown]
# ## FBMN - Filter MGF from MZmine
#
# The script takes an MGF file from [feature-based molecular networking (FBMN)](https://ccms-ucsd.github.io/GNPSDocumentation/featurebasedmolecularnetworking/) and output a filtered MGF based on a list of feature IDs.

# %% [markdown]
# #### Drag and drop your input files in the jupyter lab environment (left panel)
#
# #### Replace the filenames in the function below.
# The format looks like:
# `python3 parse_by_feature_ID.py feature_ids.txt input_mgf.txt > outfile.txt`

# %%
# !python parse_by_feature_ID.py feature_ids.txt input_mgf.txt > outfile.txt

# %% [markdown]
# #### Run the cell.

# %% [markdown]
# #### Download your filtered MGF file (left panel and right click to download).
